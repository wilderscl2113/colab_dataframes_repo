# %%
import pandas as pd

# %%
datos_alquiler = pd.read_csv('/content/drive/MyDrive/dataframe data/alquiler', sep = ';')

# %%
datos_alquiler.shape
# Out:
# (32960, 9)

# %%
datos_alquiler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           32960 non-null  object
#  1   Distrito       32960 non-null  object
#  2   Cuartos        32960 non-null  int64
#  3   Vacantes       32960 non-null  int64
#  4   Suites         32960 non-null  int64
#  5   Area           32960 non-null  int64
#  6   Valor          32943 non-null  float64
#  7   Mantenimiento  28867 non-null  float64
#  8   Impuesto       22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
datos_alquiler.head(50)
# Out:
#                   Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 0           Habitación    San Borja        1         0       0    40
# 1                 Casa   Lurigancho        2         0       1   100
# 2      Local comercial          Ate        0         4       0   150
# 3         Departamento   Pachacámac        1         0       0    15
# 4         Departamento          Ate        1         0       0    48
# 5         Departamento     Barranco        3         1       0    70
# 6         Departamento        Comas        2         0       0    50
# 7   Casa en condominio          Ate        5         4       5   750
# 8   Casa en condominio  El Agustino        2         2       0    65
# 9      Local comercial   Pachacámac        0         3       0   695
# 10        Departamento   Pachacámac        1         0       0    36
# 11        Departamento      Mi Perú        2         1       0    70
# 12        Departamento    San Borja        3         1       1    90
# ...

# %%
list(datos_alquiler['Tipo'].drop_duplicates())
# Out:
# ['Habitación',
#  'Casa',
#  'Local comercial',
#  'Departamento',
#  'Casa en condominio',
#  'Edificio completo',
#  'Flat',
#  'Tienda/Salón',
#  'Almacén',
#  'Casa comercial',
#  'Casa de villa',
#  'Terreno',
#  'Cochera',
#  'Loft',
#  'Tienda en Centro Comercial',
#  'Chacra',
#  'Terreno em condominio',
#  'Oficina',
#  'Chalet',
#  'Studio',
#  'Hotel',
#  'Local industrial']

# %%
viviendas =  ['Habitación',
 'Casa',
 'Departamento',
 'Casa en condominio',
 'Flat',
 'Casa comercial',
 'Casa de villa',
 'Cochera',
 'Loft'
]

# %%
filtro_vivienda =datos_alquiler['Tipo'].isin(viviendas)

# %%
filtro_vivienda
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
datos_viviendas = datos_alquiler[filtro_vivienda]

# %%
datos_viviendas
# Out:
#                Tipo    Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0        Habitación   San Borja        1         0       0    40   1700.0
# 1              Casa  Lurigancho        2         0       1   100   7000.0
# 3      Departamento  Pachacámac        1         0       0    15    800.0
# 4      Departamento         Ate        1         0       0    48    800.0
# 5      Departamento    Barranco        3         1       0    70   1200.0
# ...             ...         ...      ...       ...     ...   ...      ...
# 32954       Cochera  Pachacámac        0         0       0   755  14000.0
# 32955    Habitación  Pachacámac        0         0       0    27    800.0
# 32956  Departamento       Lince        3         1       2    78   1800.0
# 32957  Departamento       Rímac        2         1       0    48   1400.0
# 32958  Departamento       Rímac        2         0       0    70   3000.0
#
#        Mantenimiento  Impuesto
# 0              500.0      60.0
# ...

# %%
datos_viviendas.shape
# Out:
# (23454, 9)

# %%
datos_viviendas.index = range(datos_viviendas.shape[0])

# %%
datos_viviendas.head(50)
# Out:
#                   Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0           Habitación    San Borja        1         0       0    40   1700.0
# 1                 Casa   Lurigancho        2         0       1   100   7000.0
# 2         Departamento   Pachacámac        1         0       0    15    800.0
# 3         Departamento          Ate        1         0       0    48    800.0
# 4         Departamento     Barranco        3         1       0    70   1200.0
# 5         Departamento        Comas        2         0       0    50   1300.0
# 6   Casa en condominio          Ate        5         4       5   750  22000.0
# 7   Casa en condominio  El Agustino        2         2       0    65   1000.0
# 8         Departamento   Pachacámac        1         0       0    36   1200.0
# 9         Departamento      Mi Perú        2         1       0    70   1500.0
# 10        Departamento    San Borja        3         1       1    90   1500.0
# ...

# %%
datos_viviendas.to_csv('alquileres_viviendas.csv',sep=';')

# %%
list(datos_alquiler['Tipo'].drop_duplicates())
# Out:
# ['Habitación',
#  'Casa',
#  'Local comercial',
#  'Departamento',
#  'Casa en condominio',
#  'Edificio completo',
#  'Flat',
#  'Tienda/Salón',
#  'Almacén',
#  'Casa comercial',
#  'Casa de villa',
#  'Terreno',
#  'Cochera',
#  'Loft',
#  'Tienda en Centro Comercial',
#  'Chacra',
#  'Terreno em condominio',
#  'Oficina',
#  'Chalet',
#  'Studio',
#  'Hotel',
#  'Local industrial']

# %%
locales_comerciales =[
 'Local comercial',
 'Tienda/Salón',
 'Almacén',
 'Casa comercial',
 'Cochera',
 'Tienda en Centro Comercial',
 'Local industrial']

# %%
filtro_locales_comerciales =datos_alquiler['Tipo'].isin(locales_comerciales)

# %%
dalos_locales_comerciales = datos_alquiler[filtro_locales_comerciales]

# %%
dalos_locales_comerciales.shape
# Out:
# (9459, 9)

# %%
dalos_locales_comerciales

# %%
dalos_locales_comerciales.index = range(dalos_locales_comerciales.shape[0])

# %%
dalos_locales_comerciales.head(50)

# %%
dalos_locales_comerciales.to_csv('locales_comerciales.csv',sep=';')
