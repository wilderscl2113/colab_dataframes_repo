# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import json
import csv
import xlrd

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
with open('games.json') as f:
    data = json.load(f)

# %%
with open('archivo.csv', 'r') as archivo_csv:
    # Lee los datos del archivo CSV utilizando csv.reader
    csv_reader = csv.reader(archivo_csv)

    # Itera a través de las filas del archivo CSV
    for fila in csv_reader:
        # Procesa los datos de cada fila
        print(fila)

# %%
df = pd.DataFrame()

for saga, juegos in data["Shooter"].items():
    for juego in juegos:
        df = df.append(juego, ignore_index=True)

df

# %%
print(df)
# Out:
#                               Título      Fecha_de_Lanzamiento
# 0                       Call of Duty     29 de octubre de 2003
# 1                     Call of Duty 2     25 de octubre de 2005
# 2     Call of Duty 4: Modern Warfare    5 de noviembre de 2007
# 3            Call of Duty: Black Ops    9 de noviembre de 2010
# 4                     Counter-Strike    9 de noviembre de 2000
# 5             Counter-Strike: Source    1 de noviembre de 2004
# 6   Counter-Strike: Global Offensive      21 de agosto de 2012
# 7               Grand Theft Auto III     22 de octubre de 2001
# 8      Grand Theft Auto: San Andreas     26 de octubre de 2004
# 9                 Grand Theft Auto V  17 de septiembre de 2013
# 10                         Minecraft        17 de mayo de 2009

# %%
df= pd.read_json('/content/drive/MyDrive/dataframe data/games.json')

df.shape
# Out:
# (4, 1)

# %%
df
#
# print(df[['Título','Fecha_de_Lanzamiento']])
# Out:
#                                                             Shooter
# Call_of_Duty      [{'Título': 'Call of Duty', 'Fecha_de_Lanzamie...
# Counter_Strike    [{'Título': 'Counter-Strike', 'Fecha_de_Lanzam...
# Grand_Theft_Auto  [{'Título': 'Grand Theft Auto III', 'Fecha_de_...
# Minecraft         [{'Título': 'Minecraft', 'Fecha_de_Lanzamiento...

# %%
df_prices = pd.read_csv('/content/drive/MyDrive/dataframe data/gamepricesv2.csv')
df_prices.shape
# Out:
# (11, 1)

# %%
df_prices
# Out:
#                                     game;price
# 0                           Call of Duty;59.99
# 1                         Call of Duty 2;49.99
# 2         Call of Duty 4: Modern Warfare;39.99
# 3                Call of Duty: Black Ops;49.99
# 4                         Counter-Strike;19.99
# 5                  Counter-Strike: Source;9.99
# 6       Counter-Strike: Global Offensive;14.99
# 7                    Grand Theft Auto III;9.99
# 8          Grand Theft Auto: San Andreas;14.99
# 9                     Grand Theft Auto V;29.99
# 10                             Minecraft;26.95
# No charts were generated by quickchart
