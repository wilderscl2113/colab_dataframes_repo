# %%
import pandas as pd

# %%
alquileres = pd.read_csv('alquiler.csv',';')
# Out:
# <ipython-input-2-9249e4fb55a4>:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   alquileres = pd.read_csv('alquiler.csv',';')

# %%
alquileres

# %%
alquileres.describe()
#esto me trae datos estadisticos

# %%
#me trae los primeros rejistros
alquileres.head(10)

# %%
#me trae los ultimos rejistros
alquileres.tail(10)
# Out:
#                      Tipo     Distrito  Cuartos  Vacantes  Suites  Area  \
# 32950        Departamento   San Miguel        1         0       0    28
# 32951        Departamento          Ate        2         0       0    52
# 32952  Casa en condominio          Ate        5         3       4   450
# 32953        Departamento  Santa Anita        2         0       0    70
# 32954             Cochera   Pachacámac        0         0       0   755
# 32955          Habitación   Pachacámac        0         0       0    27
# 32956        Departamento        Lince        3         1       2    78
# 32957        Departamento        Rímac        2         1       0    48
# 32958        Departamento        Rímac        2         0       0    70
# 32959     Local comercial   Pachacámac        0         0       0   250
#
#          Valor  Mantenimiento  Impuesto
# 32950   1000.0          360.0      25.0
# 32951   1000.0          550.0       NaN
# 32952  15000.0         1711.0    2332.0
# ...

# %%
alquileres.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of                   Tipo    Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0           Habitación   San Borja        1         0       0    40  1700.0
# 1                 Casa  Lurigancho        2         0       1   100  7000.0
# 2      Local comercial         Ate        0         4       0   150  5200.0
# 3         Departamento  Pachacámac        1         0       0    15   800.0
# 4         Departamento         Ate        1         0       0    48   800.0
# ...                ...         ...      ...       ...     ...   ...     ...
# 32955       Habitación  Pachacámac        0         0       0    27   800.0
# 32956     Departamento       Lince        3         1       2    78  1800.0
# 32957     Departamento       Rímac        2         1       0    48  1400.0
# 32958     Departamento       Rímac        2         0       0    70  3000.0
# ...

# %%
alquileres_dpto = alquileres.groupby(['Distrito','Tipo'])

# %%
alquileres_dpto.mean()
# Out:
#                                              Cuartos   Vacantes    Suites  \
# Distrito                Tipo
# Ancón                   Almacén             0.000000   1.818182  0.000000
#                         Casa                2.125000   0.875000  0.187500
#                         Casa comercial      0.000000  50.000000  0.000000
#                         Casa de villa       1.333333   0.166667  0.000000
#                         Casa en condominio  2.318182   1.318182  0.909091
# ...                                              ...        ...       ...
# Villa María del Triunfo Edificio completo   0.000000  25.000000  0.000000
#                         Local comercial     0.000000   1.000000  0.000000
#                         Oficina             2.500000   5.000000  0.500000
#                         Terreno             0.000000   0.000000  0.000000
#                         Tienda/Salón        0.000000   0.333333  0.000000
#
# ...

# %%
alquileres_dpto.count()
# Out:
#                                             Cuartos  Vacantes  Suites  Area  \
# Distrito                Tipo
# Ancón                   Almacén                  11        11      11    11
#                         Casa                     16        16      16    16
#                         Casa comercial            1         1       1     1
#                         Casa de villa             6         6       6     6
#                         Casa en condominio       22        22      22    22
# ...                                             ...       ...     ...   ...
# Villa María del Triunfo Edificio completo         1         1       1     1
#                         Local comercial           1         1       1     1
#                         Oficina                   2         2       2     2
#                         Terreno                   3         3       3     3
#                         Tienda/Salón              3         3       3     3
#
# ...
